# %% [markdown]
# <a href="https://colab.research.google.com/github/jjohn120/DATA151_group_project/blob/main/Coding_for_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df4 =pd.read_excel('New Data.xlsx')
print (df4)
plt.figure(figsize=(12,6))
sns.heatmap(data=df4.corr(), cmap='viridis', annot=True)
# Out:
#      Year  Median  Average  # Sold   Interest  # Data Point
# 0    1971   25200    28300     656   7.541750             1
# 1    1972   27600    30500     718   7.383269             2
# 2    1973   32500    35500     634   8.044808             3
# 3    1974   35900    38900     519   9.187115             4
# 4    1975   39300    42600     549   9.047115             5
# 5    1976   44200    48000     646   8.865849             6
# 6    1977   48800    54200     819   8.845192             7
# 7    1978   55700    62500     817   9.641731             8
# 8    1979   62900    71800     709  11.203654             9
# 9    1980   64600    76400     545  13.742115            10
# 10   1981   68900    83000     436  16.641509            11
# 11   1982   69300    83900     412  16.043654            12
# 12   1983   75300    89800     623  13.235385            13
# 13   1984   79900    97600     639  13.877692            14
# 14   1985   84300   100800     688  12.430192            15
# ...

# %% [markdown]
# # New Section
